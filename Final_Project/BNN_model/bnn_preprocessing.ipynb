# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc, precision_recall_curve
from google.colab import files


###### Load the dataset
'''
read (string) -> dataframe
'''
# if fails in file path so rewrite this part of this code so it fits for both local computer and cloud
'''
upload (file) -> dataframe
'''


file_path = "/mnt/data/cisc_352_dataaset.csv"
try:
    df = pd.read_csv(file_path)
except FileNotFoundError:
    print("Dataset not found. Please upload your CSV file.")
    uploaded = files.upload()
    file_path = list(uploaded.keys())[0]
    df = pd.read_csv(file_path)

# %%
###### Preprocessing data

df.drop(columns=['id'], inplace=True, errors='ignore')  # Drops 'id' -> dataframe (569, 32) from (569, 33)
df.drop(columns=['Unnamed: 32'], inplace=True, errors='ignore')  # Drops 'Unnamed: 32' -> dataframe (569, 31)
df['diagnosis'] = LabelEncoder().fit_transform(df['diagnosis']) # Encoding the labels -> output labels (0/1)

'''
X = [[]....]
y = []
'''
X = df.drop(columns=['diagnosis']).values # x values are values with everything except for output labels in this dataset -> (569,30)
y = df['diagnosis'].values # y values are output labels -> (569)


# Normalizing features
scaler = StandardScaler()
X = scaler.fit_transform(X) # These two lines standardlizes the graph. centering around the mean and scales the graphs accordingly 



# # Visualize the means
# means = X.mean(axis=0)
# feature_names = df.drop(columns=['diagnosis']).columns.tolist()  # Get feature names
# print(feature_names)

# plt.figure(figsize=(12, 6))
# plt.bar(feature_names, means)
# plt.xticks(rotation=45, ha='right')
# plt.ylabel('Mean')
# plt.title('Mean of Normalized Features')
# plt.tight_layout()
# plt.show()

# # Visualize the distributions of normalized features
# num_features = X.shape[1]
# plt.figure(figsize=(15, 10))
# for i in range(num_features):
#     plt.subplot(5, 6, i + 1)  # Assuming a maximum of 30 features, adjust if needed.
#     plt.hist(X[:, i], bins=30, alpha=0.7)
#     plt.title(feature_names[i])
# plt.tight_layout()
# plt.show()

# # Visualize the distributions of original features before normalization
# original_X = df.drop(columns=['diagnosis']).values
# original_feature_names = df.drop(columns=['diagnosis']).columns.tolist()
# num_original_features = original_X.shape[1]

# plt.figure(figsize=(15, 10))
# for i in range(num_original_features):
#     plt.subplot(5, 6, i + 1)
#     plt.hist(original_X[:, i], bins=30, alpha=0.7)
#     plt.title(original_feature_names[i])
# plt.tight_layout()
# plt.show()
